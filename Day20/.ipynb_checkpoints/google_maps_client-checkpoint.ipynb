# %%
import requests
from urllib.parse import urlencode
from urllib.parse import urlparse, parse_qsl
from _kluce import api_key as GOOGLE_API_KEY

# %% [markdown]
# Google Maps Client API

# %%
class GoogleMapsClient(object):
    lat = None
    lng = None
    data_type = 'json'
    location_query = None
    api_key = None
    
    def __init__ (self, api_key=None, asdress_or_postal_code=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        if api_key == None:
            raise Exception('API key is required')
        self.api_key = api_key
        self.location_query = asdress_or_postal_code
        if self.location_query != None:
            self.extract_lat_lng()
    
    def extract_lat_lng(self, location=None):
        loc_query = self.location_query
        if location != None:
            loc_query=location
        endpoint = f"https://maps.googleapis.com/maps/api/geocode/{self.data_type}"
        params = {"address": loc_query, "key": self.api_key}
        url_params = urlencode(params)

        url = f"{endpoint}?{url_params}"
        r = requests.get(url)
        if r.status_code not in range (200,299):
            return {}
        latlng = {}
        try:
            latlng = r.json()['results'][0]['geometry']['location']
        except:
            pass
        lat, lng = latlng.get("lat"), latlng.get("lng")
        self.lat = lat
        self.lng = lng
        return lat, lng
    
    def search(self, keyword="China Food", radius=1000,  location = None):
        lat, lng = self.lat, self.lng
        if location != None:
            lat, lng = self.extract_lat_lng(location)
        endpoint = f'https://maps.googleapis.com/maps/api/place/nearbysearch/{self.data_type}'
        params = {
            "key": self.api_key,
            "location": f"{lat},{lng}",
            "radius": radius,
            "keyword": keyword
        }
        params_encoded = urlencode(params)
        places_url = f"{endpoint}?{params_encoded}"
        r = requests.get(places_url)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def detail(self, place_id='ChIJB8F-_QHFw0cRkIcY_Zn5M04', fields=["name", "rating", "formatted_phone_number", "formatted_address"]):
        #  Detail lookup
        detail_base_endpoint = f'https://maps.googleapis.com/maps/api/place/details/{self.data_type}'
        detail_params = {
            "place_id": f"{place_id}",
            "fields": ",".join(fields),
            "key": self.api_key
        }
        detail_params_encoded = urlencode(detail_params)
        detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"
        r = requests.get(detail_url)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

# %%
client = GoogleMapsClient(api_key=GOOGLE_API_KEY, asdress_or_postal_code='90086')
print(client.lat, client.lng)
# Out:
# 34.06 -118.24

# %%
client.search("China food", location="London")
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AeJbb3eWldsOrPZwY4ay-64dyuSkbI3dwVSoxa5AEFzSEOiHwLvpIqtnvcRc3CgZu6SlSWltZkGxt6QOPUnYlIUrE2As9SegoMH5g5fpYyO768jgM8ET5HL26MFUvQvvjdMOr2GsI1eSyX4uYAcUKOAASu98OnRvH375MBgw7IMdyKLwgfX9vs8UWbcMFSXOC5hvuU0MzqDwdJjd2ci3v8JoKh81mYv_kE1hF_aSrvm7Jra1EzweDTRJGn8eM1ckeP9DKPR5k9kb-qrGHla2DEepHZosTrzlTtO5MRWerCH087YjcKzNPJYnjRIgFJM1CdjR8v6EtucIJKq4PKj2p79IjtMrlF_L5XlSqkQh6GjwvorjC-vW15Ksu09kEzf3jP8s_DEY8ub90oj0AP_detRki4_-_gnqkUVpilGUSOCRT4v6oTB4yNaas5a_yxsz',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5162436, 'lng': -0.1316125},
#     'viewport': {'northeast': {'lat': 51.51762912989272,
#       'lng': -0.1302695201072778},
#      'southwest': {'lat': 51.51492947010728, 'lng': -0.1329691798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'China Express',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJLSGcGQUbdkgR1BtMgx952nk',
#    'plus_code': {'compound_code': 'GV89+F9 London, United Kingdom',
#     'global_code': '9C3XGV89+F9'},
#    'rating': 5,
#    'reference': 'ChIJLSGcGQUbdkgR1BtMgx952nk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '29 Oxford St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5118738, 'lng': -0.1303215},
#     'viewport': {'northeast': {'lat': 51.51339402989272,
#       'lng': -0.1289123701072778},
#      'southwest': {'lat': 51.51069437010728, 'lng': -0.1316120298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'New Loon Fung Restaurant',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1680,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109582064124743083707">Yáiza Maldonado</a>'],
#      'photo_reference': 'AeJbb3dU18znQ-6tnWwuiZa4WiLoetNU8F2HEjTelbCksV3KewywERBuwKEHq-TPS06SgN2AY0nO6UxIYHvqA9l1Xuq_5xBGbRxs_W3mH61YboxKOLBJqCccAt471RPk4TNXxXBZEDsZZuz4boKVoEiWbBHOOvfdKGwNrgXn5bqw-oBRO6Pl',
#      'width': 3648}],
#    'place_id': 'ChIJfWTpZtIEdkgRbn3rSRm1-2M',
#    'plus_code': {'compound_code': 'GV69+PV London, United Kingdom',
#     'global_code': '9C3XGV69+PV'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJfWTpZtIEdkgRbn3rSRm1-2M',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1101,
#    'vicinity': '1/F-4 F, 42-43 Gerrard St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5117595, 'lng': -0.1298617},
#     'viewport': {'northeast': {'lat': 51.51307182989271,
#       'lng': -0.1285210701072778},
#      'southwest': {'lat': 51.51037217010726, 'lng': -0.1312207298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Bun House',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109130797092980246511">Midori Okamoto</a>'],
#      'photo_reference': 'AeJbb3dUJh0FoH5UHKaqMMl70A8VPwLV-4zgCFZMa40pRXbsDpQRNlssNY7AYx-j0etaY83wBDyAKuGzj0P0qd3BIoQfLSPzakv3Jd-N1s-v9xGmRj9-MQxgIDGK29mxnCm89S5j7mZ0STBHQQTwNjBLS49rwdWo9MarztgvY6tGZay9YukL',
#      'width': 5333}],
#    'place_id': 'ChIJxfwuvtIEdkgRzkGKnK1ssek',
#    'plus_code': {'compound_code': 'GV6C+P3 London, United Kingdom',
#     'global_code': '9C3XGV6C+P3'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJxfwuvtIEdkgRzkGKnK1ssek',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'meal_takeaway',
#     'night_club',
#     'cafe',
#     'restaurant',
#     'food',
#     'bar',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1709,
#    'vicinity': '26-27 Lisle St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5115808, 'lng': -0.1314411},
#     'viewport': {'northeast': {'lat': 51.51301707989272,
#       'lng': -0.1299560201072778},
#      'southwest': {'lat': 51.51031742010728, 'lng': -0.1326556798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Chuan • Royal China',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3360,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115761046697589562036">A Google User</a>'],
#      'photo_reference': 'AeJbb3elSL2M7nLkm2OJymu9wqre48UnIUvwk2a2skzY6kBdoVYfTgMPI3wvogCtNCyPD-zxTxk0Ll9Sc7q-oiqnc-oLUMZy2aPvkOu0MgCFB1gjxCCdEq2iIb53TLIPy5mvoV2-HUZjkrj9Joxq0bpYDYw7QW0vNbAF6s5PiRWlE_KOrURq',
#      'width': 5040}],
#    'place_id': 'ChIJyUGHauAFdkgRwaYOKMpPpDo',
#    'plus_code': {'compound_code': 'GV69+JC London, United Kingdom',
#     'global_code': '9C3XGV69+JC'},
#    'rating': 4.5,
#    'reference': 'ChIJyUGHauAFdkgRwaYOKMpPpDo',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 105,
#    'vicinity': '30 Gerrard St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5110408, 'lng': -0.1310761},
#     'viewport': {'northeast': {'lat': 51.51236912989272,
#       'lng': -0.1297992701072778},
#      'southwest': {'lat': 51.50966947010728, 'lng': -0.1324989298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Jinli Chinese Restaurant',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112832949037105787767">Ergun Polat</a>'],
#      'photo_reference': 'AeJbb3eL-p4iBIIfgmxiderhdZwmwJO2b5XuDUI1RSJWjXxtIFJVnu6JGSvQZ8G_N56uxlSjoAe0X1fLC3xsH0uI7_-4Ktf5NpzUID2n6R_ToMhcVqT1Gu0DhakyGm21dwOrO1gkfW45B748ePOKmuTP3IDcc-s8EkXSSHN3DUdh1tzNc3-Q',
#      'width': 4032}],
#    'place_id': 'ChIJw6VER9IEdkgRWRATrwtBuGs',
#    'plus_code': {'compound_code': 'GV69+CH London, United Kingdom',
#     'global_code': '9C3XGV69+CH'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJw6VER9IEdkgRWRATrwtBuGs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 480,
#    'vicinity': '4 Leicester St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5112315, 'lng': -0.131513},
#     'viewport': {'northeast': {'lat': 51.51256417989272,
#       'lng': -0.1301470201072778},
#      'southwest': {'lat': 51.50986452010728, 'lng': -0.1328466798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "May's Sweet Bite",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117104816644453575846">Miss DjKpopMix</a>'],
#      'photo_reference': 'AeJbb3dX7T8DnyXRX773pp8mcomYMeTpnKpgG337OMTFTX3hgAYqrAmmv1Qt-6ZAlspYTWoM0dPdeutBYSIKAnOmBHmH_0QnvLr21aFFS8HZC4zRrqMnrg3pz0XgoizOsKHdALbu-mb0m66Ch3plPrHZOusJDKAC9yNG8zFfw1CtbwN0BtKH',
#      'width': 3024}],
#    'place_id': 'ChIJz0TBH2kFdkgRfSSj4enpDKE',
#    'plus_code': {'compound_code': 'GV69+F9 London, United Kingdom',
#     'global_code': '9C3XGV69+F9'},
#    'rating': 4.8,
#    'reference': 'ChIJz0TBH2kFdkgRfSSj4enpDKE',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 121,
#    'vicinity': '4 Lisle St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5120993, 'lng': -0.1300565},
#     'viewport': {'northeast': {'lat': 51.51350822989271,
#       'lng': -0.1287187201072778},
#      'southwest': {'lat': 51.51080857010727, 'lng': -0.1314183798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Food House',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112233120332427975003">Eunkyoung Son</a>'],
#      'photo_reference': 'AeJbb3fsHW-30gqk4IfAjJN9s0fHAoXfJGgui4vLznEPWAour8UMItpiUUjpHiAMIbPzO-6LzfA2rnu8YpoKw-iBUDhkue7oPWFvQygt53bZC9_8Qn_oHo4NzARZlcbADd22h1xIBedN5XCDWAu6scWiRrkI7rSdy_hzbL__K09kRdGAw2sC',
#      'width': 4032}],
#    'place_id': 'ChIJVfCSY9IEdkgRyD-51EvpFIo',
#    'plus_code': {'compound_code': 'GV69+RX London, United Kingdom',
#     'global_code': '9C3XGV69+RX'},
#    'rating': 4.2,
#    'reference': 'ChIJVfCSY9IEdkgRyD-51EvpFIo',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 76,
#    'vicinity': '46 Gerrard St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5117468, 'lng': -0.129929},
#     'viewport': {'northeast': {'lat': 51.51305582989272,
#       'lng': -0.1285759201072778},
#      'southwest': {'lat': 51.51035617010728, 'lng': -0.1312755798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Imperial China',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116830001764383643520">Catherine Joseph</a>'],
#      'photo_reference': 'AeJbb3dmAlwLJrtwT-LlC_3PxzU6gscjp2lcczCH6oi34Dk7Anft9TU34pmdAEswzdDD2gZ7dlSIwJpNIvBd9GHyuZPXpV0ukLPmX-G1nG83jbFcXpFkjwpJx6yDQ4XtKAynEzJwINVHyPml90cQHPhr-NvsUpd_QNkqm8wOYwldoT2DAx_-',
#      'width': 4032}],
#    'place_id': 'ChIJjU1LZdIEdkgR8_B7n3kXglY',
#    'plus_code': {'compound_code': 'GV6C+M2 London, United Kingdom',
#     'global_code': '9C3XGV6C+M2'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJjU1LZdIEdkgR8_B7n3kXglY',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1367,
#    'vicinity': '25a White Bear Yard, Lisle St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5079222, 'lng': -0.1328036},
#     'viewport': {'northeast': {'lat': 51.50923407989271,
#       'lng': -0.1315660201072778},
#      'southwest': {'lat': 51.50653442010727, 'lng': -0.1342656798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Imperial Treasure Fine Chinese Cuisine',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3764,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111343807096735236740">Habib Al Mulla</a>'],
#      'photo_reference': 'AeJbb3fxVWY3fx_nKDTUTk0dJAR9RCgkLdEWX4Gg1oDPCmCVoom7A-VG5xkKH4ko79w_RtgmKmTxPNlxEmjyowCIdgdLhCLuAhQtYLL8tOM9QRS03fqWwO_7_OFeUaL1IoHcuofAB7uzvmbCGQ1jSgHsxaEWFNciUP70t4vDIuw0J-WPXd0L',
#      'width': 2479}],
#    'place_id': 'ChIJpbwBCY4FdkgR4DAgeXXfXro',
#    'plus_code': {'compound_code': 'GV58+5V London, United Kingdom',
#     'global_code': '9C3XGV58+5V'},
#    'price_level': 4,
#    'rating': 4.2,
#    'reference': 'ChIJpbwBCY4FdkgR4DAgeXXfXro',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 358,
#    'vicinity': '9 Waterloo Pl, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5119233, 'lng': -0.1310272},
#     'viewport': {'northeast': {'lat': 51.51319572989271,
#       'lng': -0.1296847701072778},
#      'southwest': {'lat': 51.51049607010727, 'lng': -0.1323844298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Far East Chinese',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108608036763406695164">A Google User</a>'],
#      'photo_reference': 'AeJbb3cUcFU23E0uLCIIP3qLkvF3RzVRSQDqecIQk4y-MHzpS6n4DyzKv8mKJiZft6uItQIQ1f057KIGSVF1hyXzFkWVzkDfVdSJc4Hp2tBI8eNPIBLrrnRGR_OpwQgiKI9F2Skzk68v-SLJAInQaS2TIVVVSW9cDlKDKyW2izTX-8qpln55',
#      'width': 2302}],
#    'place_id': 'ChIJ03seTNIEdkgR20aDTUfgNX4',
#    'plus_code': {'compound_code': 'GV69+QH London, United Kingdom',
#     'global_code': '9C3XGV69+QH'},
#    'rating': 3.2,
#    'reference': 'ChIJ03seTNIEdkgR20aDTUfgNX4',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 217,
#    'vicinity': '13 Gerrard St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5111111, 'lng': -0.1311111},
#     'viewport': {'northeast': {'lat': 51.51242222989272,
#       'lng': -0.1298304201072778},
#      'southwest': {'lat': 51.50972257010728, 'lng': -0.1325300798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Joy King Lau',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111774639240429184035">Ashrak Ahmed</a>'],
#      'photo_reference': 'AeJbb3d_obYKTSL6QC6GqjSN-VbE5ynwEPB3lg3Wrr1SbsBv7KKHn1-tfeHSL1syOCAm3LaNS909VFq4JvPGHRyeq2ttbcaejcVQk-G2qdjBNEAJhJOX9_f-NGzzJagJYgn71_itMtsymIKMoCEhKmtOsMkbqYohi0gaMb7Ei4piSfTn1Nru',
#      'width': 4032}],
#    'place_id': 'ChIJOT5hc9IEdkgR4UiChmyE3qY',
#    'plus_code': {'compound_code': 'GV69+CH London, United Kingdom',
#     'global_code': '9C3XGV69+CH'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJOT5hc9IEdkgR4UiChmyE3qY',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1751,
#    'vicinity': '3 Leicester St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5116771, 'lng': -0.1278513},
#     'viewport': {'northeast': {'lat': 51.51297677989272,
#       'lng': -0.1264543701072778},
#      'southwest': {'lat': 51.51027712010728, 'lng': -0.1291540298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Wok To Walk Cranbourn St',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116861548726997500410">Wok To Walk</a>'],
#      'photo_reference': 'AeJbb3eha5ftGcBquNwY2Q9wMfGO269i6aIlMNKV325XcOiF8FWYt8_iK6IwyAKBa44AK9UvZHK7r2JWSc9fcZVsCp6U7QqZR6H2yv_wcG9M6vOkbzcMqy8oSyG9isk9hKtEk2rZmrbe0stw_GglgSw0ijx_S8M9-XoTA4V0dVAVNCvaEI0M',
#      'width': 1200}],
#    'place_id': 'ChIJGZ_VkM0EdkgRDUXdCs_-I24',
#    'plus_code': {'compound_code': 'GV6C+MV London, United Kingdom',
#     'global_code': '9C3XGV6C+MV'},
#    'price_level': 1,
#    'rating': 4.3,
#    'reference': 'ChIJGZ_VkM0EdkgRDUXdCs_-I24',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1656,
#    'vicinity': '22 Cranbourn St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5109383, 'lng': -0.1319491},
#     'viewport': {'northeast': {'lat': 51.51230522989273,
#       'lng': -0.1305297201072778},
#      'southwest': {'lat': 51.50960557010729, 'lng': -0.1332293798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Orient London',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2976,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114249296228430346322">Jared Kelly</a>'],
#      'photo_reference': 'AeJbb3eGamtNbEL0nEG62N_03edv1CGuNGHwKlRtoNasdgwDfs3MEhvbKCmjtfWyxjqRfrb8yR7z3Z1DSmLMWh8x-NP_EHR-MaP4sUSzo8GGK-8DD-GCo12d1wi5jF4_KaFKnIhtXI4CQ1ot7yKm7LuKd5McKR9i8pTmWk5LIK1W36Crn02b',
#      'width': 3968}],
#    'place_id': 'ChIJXQZ2NdIEdkgRQPMVL2rSu08',
#    'plus_code': {'compound_code': 'GV69+96 London, United Kingdom',
#     'global_code': '9C3XGV69+96'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJXQZ2NdIEdkgRQPMVL2rSu08',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1140,
#    'vicinity': '15 Wardour St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5121112, 'lng': -0.1298791},
#     'viewport': {'northeast': {'lat': 51.51348762989272,
#       'lng': -0.1284559201072778},
#      'southwest': {'lat': 51.51078797010727, 'lng': -0.1311555798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'New China 中华楼',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 740,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114289955629765649624">A Google User</a>'],
#      'photo_reference': 'AeJbb3ewfFat79lVfnnARBlXVnAKxUQzrL0hdajR12DLOO9_IYcjKphuPlTqzeGNrjt2hebzGPRDv-eK-rkofVO3FZ7pvwbpFeywlCTeMDdN85rj-ze4QOp-sQO6bXmiI7j9dAJn7EMAUGV6RHD6PvotO5TvqqPAoayqHxOWqUFpG59X9V4',
#      'width': 1320}],
#    'place_id': 'ChIJyRkufdIEdkgR99B01tLhoe0',
#    'plus_code': {'compound_code': 'GV6C+R2 London, United Kingdom',
#     'global_code': '9C3XGV6C+R2'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJyRkufdIEdkgR99B01tLhoe0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 557,
#    'vicinity': '48 Gerrard St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.509598, 'lng': -0.1260993},
#     'viewport': {'northeast': {'lat': 51.51093542989272,
#       'lng': -0.1246451701072778},
#      'southwest': {'lat': 51.50823577010728, 'lng': -0.1273448298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Xi Home Dumplings and Buns喜家饺子店',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1333,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100107461247829653313">A Google User</a>'],
#      'photo_reference': 'AeJbb3e9H3yE6r0y-sTgqUrPWfHWHTWkDvznM0oYQHTfqUhIdtn3lFk_iPH3-PYUTtRx8swq-KgL434PK2Hczjt2WJu1fHDQ-az5Duemxi6ig6ZodSnHXpGhYGg0a36nScnkffUAIwlddMlglwvdnE1j_f0wDTu_-vVbIoSCMuxCtSvjtp-D',
#      'width': 2000}],
#    'place_id': 'ChIJk_QzbuwFdkgRg3YBcVblVcM',
#    'plus_code': {'compound_code': 'GV5F+RH London, United Kingdom',
#     'global_code': '9C3XGV5F+RH'},
#    'rating': 4.5,
#    'reference': 'ChIJk_QzbuwFdkgRg3YBcVblVcM',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 424,
#    'vicinity': '43 Chandos Pl, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5151074, 'lng': -0.1409403},
#     'viewport': {'northeast': {'lat': 51.51635627989272,
#       'lng': -0.1396983201072778},
#      'southwest': {'lat': 51.51365662010728, 'lng': -0.1423979798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Wok To Walk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113019176933118349761">A Google User</a>'],
#      'photo_reference': 'AeJbb3fKjew4uFnvHpzShNLLkaENPX0HqXA621MzkQZ-_5y-tttyRMFtq80D8kuteAMjPcf3p7ePMew9cpPU9H5vRN1GaNb5ja5vgvnHYHeTwG0DOPm-hu99up34dvd1WfjBuyzLRX26F0orn1vx22fIWM9a9OjrZJtXtD3lbCJ0tqai3aJn',
#      'width': 1200}],
#    'place_id': 'ChIJdS7CVdUEdkgRpMaPBLpsB3I',
#    'plus_code': {'compound_code': 'GV85+2J London, United Kingdom',
#     'global_code': '9C3XGV85+2J'},
#    'price_level': 1,
#    'rating': 4.3,
#    'reference': 'ChIJdS7CVdUEdkgRpMaPBLpsB3I',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1212,
#    'vicinity': '15 Argyll St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5116895, 'lng': -0.1302077},
#     'viewport': {'northeast': {'lat': 51.51300027989272,
#       'lng': -0.1288451701072778},
#      'southwest': {'lat': 51.51030062010727, 'lng': -0.1315448298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'New Young Cheng',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104077583738709762057">Neil Gould</a>'],
#      'photo_reference': 'AeJbb3e_edsW7v_o3REPuw8SnHduhSA09dLoZeqFXJs7cqgHH6ZWcAD0LZ9t7Dqt8GyDHp3yykhk8sI-W0b3UmfDglNDZj2RxydNQluEwueKh3UKnOApT5aqST8fdPQd9_jGf5-CKB5jY4eYI4t45LU6l3UXYuXzx_LbK_6iyCN9W61sBhNa',
#      'width': 5312}],
#    'place_id': 'ChIJnyVsq50FdkgRHNa_Dzh3_uQ',
#    'plus_code': {'compound_code': 'GV69+MW London, United Kingdom',
#     'global_code': '9C3XGV69+MW'},
#    'rating': 3.9,
#    'reference': 'ChIJnyVsq50FdkgRHNa_Dzh3_uQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 172,
#    'vicinity': '22 Lisle St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5117139, 'lng': -0.1301306},
#     'viewport': {'northeast': {'lat': 51.51302272989273,
#       'lng': -0.1287802701072778},
#      'southwest': {'lat': 51.51032307010728, 'lng': -0.1314799298927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Beijing Dumpling',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117010909077961730892">Joy</a>'],
#      'photo_reference': 'AeJbb3fO2N5TMjDg5d_pQK_sEOJu93onHBH84y93Hp9KgjJ8-50toGtHPCQrj0YtN1wLmXa68HpYJH5AzrBtB3xNM52F0KbvMdA7nLoD1HrRRPuMViTF6u5fiH4KAb6Tl0FiGrcblzRAmrZDLKNqTpsz9BHBb6jCYLCfKoIRzgRqFz2jZHuq',
#      'width': 4032}],
#    'place_id': 'ChIJ456HZdIEdkgRZ2SUdGU9cT0',
#    'plus_code': {'compound_code': 'GV69+MW London, United Kingdom',
#     'global_code': '9C3XGV69+MW'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJ456HZdIEdkgRZ2SUdGU9cT0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2041,
#    'vicinity': '23 Lisle St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5110204, 'lng': -0.1319987},
#     'viewport': {'northeast': {'lat': 51.51239132989273,
#       'lng': -0.1305890201072778},
#      'southwest': {'lat': 51.50969167010728, 'lng': -0.1332886798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Old Town 97',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112363523782385978744">Adisorn Phano</a>'],
#      'photo_reference': 'AeJbb3fQWy4sTibT6j-TkxwKD2WoZ1VamOyfeEPLi1Mi48uxZ8o0YC3pzkAd7cijSEfxyZp9Tblty2rdsx0h8o6ok0_HaT6TxHBPB8uYMREn6Xb1JtU4q6wRHVZHTx7iHGpI00lqVbAEI1fSvG8tdPAem1bWXj3M8wrPKQO689T3E9dx43aV',
#      'width': 4640}],
#    'place_id': 'ChIJt0WENdIEdkgRQh8RLqsRXJs',
#    'plus_code': {'compound_code': 'GV69+C6 London, United Kingdom',
#     'global_code': '9C3XGV69+C6'},
#    'rating': 3.6,
#    'reference': 'ChIJt0WENdIEdkgRQh8RLqsRXJs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 766,
#    'vicinity': '19 Wardour St, London'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.5140199, 'lng': -0.1297057},
#     'viewport': {'northeast': {'lat': 51.51538387989271,
#       'lng': -0.1282723201072778},
#      'southwest': {'lat': 51.51268422010727, 'lng': -0.1309719798927222}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Mr. Meng',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1620,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107491520916451289023">O L</a>'],
#      'photo_reference': 'AeJbb3egMmd1fueVzjwtuKpe9Zt8DPl41LH3JoJZ0OqSsk1WEkfp2jLUfZLfiJCJIkCBYhKHk_ImUTt7avNQsI3w3czrvQYsKrfxYscecxxyMHFIx_k8R7FI5EW8o7sB2O3XlGxt4PCQ5W8wyymRbPxuHKt2g_3KjX35qac1BHRkcMeZhwuP',
#      'width': 2160}],
#    'place_id': 'ChIJL7DW81MFdkgRQhylV5s4ix0',
#    'plus_code': {'compound_code': 'GV7C+J4 London, United Kingdom',
#     'global_code': '9C3XGV7C+J4'},
#    'rating': 3.9,
#    'reference': 'ChIJL7DW81MFdkgRQhylV5s4ix0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 284,
#    'vicinity': '103 Charing Cross Rd, London'}],
#  'status': 'OK'}

# %%
client.detail(place_id='ChIJLSGcGQUbdkgR1BtMgx952nk')
# Out:
# {'html_attributions': [],
#  'result': {'formatted_address': '29 Oxford St, London W1D 2DR, UK',
#   'name': 'China Express',
#   'rating': 5},
#  'status': 'OK'}
